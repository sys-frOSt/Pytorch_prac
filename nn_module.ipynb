# %% [markdown]
# <a href="https://colab.research.google.com/github/sys-frOSt/Pytorch_pipeline_practice/blob/main/nn_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn

# %%
#NN model use for training a nueral network using one neuron
class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.linear1=nn.Linear(num_features,3)#(num_,hidenlayer number of neuron)
    self.relu=nn.ReLU()
    self.linear2=nn.Linear(3,1)
    self.sigmoid=nn.Sigmoid()

  def forward(self,features):
    out =self.linear1(features)
    out=self.relu(out)
    out=self.linear2(out)
    out-self.relu(out)
    return out

# %%
#dataset
features=torch.rand(10,5)
#model
model=Model(features.shape[1])
#forward pass
model(features)
# Out:
# tensor([[0.3487],
#         [0.3751],
#         [0.3801],
#         [0.3485],
#         [0.3608],
#         [0.3789],
#         [0.3654],
#         [0.3682],
#         [0.3592],
#         [0.3738]], grad_fn=<SigmoidBackward0>)

# %%
model.linear1.bias
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_779/898945831.py in <cell line: 0>()
# ----> 1 model.linear1.bias
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1966             if name in modules:
#    1967                 return modules[name]
# -> 1968         raise AttributeError(
#    1969             f"'{type(self).__name__}' object has no attribute '{name}'"
#    1970         )
#
# AttributeError: 'Model' object has no attribute 'linear1'

# %%
# !pip install torchinfo

# %%
from torchinfo import summary

# %%
summary(model,input_size=(10,5))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Model                                    [10, 1]                   --
# ├─Linear: 1-1                            [10, 3]                   18
# ├─ReLU: 1-2                              [10, 3]                   --
# ├─Linear: 1-3                            [10, 1]                   4
# ├─ReLU: 1-4                              [10, 1]                   --
# ...
# Total params: 22
# Trainable params: 22
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.00
# ...
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ...

# %%
#using sequential containers
class Model(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.network=nn.Sequential(
         nn.Linear(num_features,3),#(num_,hidenlayer number of neuron)
         nn.ReLU(),
         nn.Linear(3,1),
         nn.Sigmoid(),
         )

  def forward(self,features):
    out =self.network(features)
    return out

# %%
model.network[0].weight
# Out:
# Parameter containing:
# tensor([[ 0.0471, -0.3386,  0.1020, -0.1923,  0.2993],
#         [ 0.3015,  0.0762,  0.0865,  0.1918, -0.4214],
#         [-0.3244, -0.1480,  0.0808, -0.3490,  0.1291]], requires_grad=True)
